# %% [markdown]
# # 👉 Exploratory Data Analysis - Sports (Level - Advanced)  # 5
#
# ## Intern Project Done By : Sivasakthivel R   |   Date: 19.05.2021
# ### Mail ID: rsivasakthivel@gmail.com
#
# ### Programming Language (IDE) : Python 3.8.5

# %% [markdown]
# 👉 Data Science & Business Analytics Tasks:
#
# Task#5 : Exploratory Data Analysis - Sports (Level - Advanced).
#
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘Indian Premier League’.
#
# ● As a sports analysts, find out the most successful teams, players and factors contributing win or loss of a team.
#
# ● Suggest teams or players a company should endorse for its products.
#
# ● You can choose any of the tool of your choice. (Python/R/Tableau/PowerBI/Excel/SAP/SAS).
#
# ● Dataset: https://bit.ly/34SRn3b
#
# ● Advanced Level - Create storyboards. Screen-record along with your audio explaining the charts and interpretations. Use annotations, animation and images.
#
# ● Task submission:
#
# 1. Create the dashboards and/or storyboard and record it.
# 2. Upload the recording on Youtube, share the link on LinkedIn.
# 3. Submit LinkedIn post link in Task Submission Form when shared.
# 4. Please read FAQs on how to submit the tasks.

# %% [markdown]
# #### 👉 Supress Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 👉 Import the Numpy and Pandas Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 👉 Load the iris dataset

# %%
df1 = pd.read_csv("C:/Users/SIVA/Documents/Siva/InternShip/The Spark Foundation/Task-5/matches.csv")
df2 = pd.read_csv("C:/Users/SIVA/Documents/Siva/InternShip/The Spark Foundation/Task-5/deliveries.csv")

# %%
df2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df1
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df1.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df1 = df1.drop(labels = ['umpire1', 'umpire2', 'umpire3'], axis = 1)

# %%
df1
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# #### 👉 We have dropped the umpire1, umpire2, umpire3 columns from the dataset as it is not needed according to the analysis that has been provided to us.

# %% [markdown]
# #### 👉 Now lets check the info again

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
sns.heatmap(df1.isnull(), yticklabels= False, cbar = False, cmap = 'plasma');

# %% [markdown]
# #### 👉 As we can see city, winner, player_of_match columns few are still null which can be settled later

# %%
df1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ### 👉Total number of matches hosted by cities

# %%
df1['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %% [markdown]
# ### 👉Total Number of matches played in different stadiums across seasons

# %%
plt.figure(figsize = (15,6))
plt.xticks(rotation = 'vertical')
sns.countplot(x = 'city', data = df1);

# %%
plt.figure(figsize = (15,6))
plt.xticks(rotation = 90)
sns.countplot(x = 'venue', data = df1);

# %% [markdown]
# #### 👉 Mumbai in total hosted the maximum number of matches but Eden gardens of kolkata is recorded as the stadium where the maximum number of matches has been played.

# %% [markdown]
# ### 👉Who is the most successfull player in the whole IPL tournament?

# %%
#we have tried to plot the countplot of the number of man of the matches by every player
plt.figure(figsize = (50,8))
plt.xticks(rotation = 'vertical')
sns.countplot(x = 'player_of_match', data = df1);

# %% [markdown]
# #### 👉 As the countplot is large so to specify it correctly

# %%
df1.player_of_match.value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
#                   ..
# MF Maharoof        1
# MR Marsh           1
# M Kartik           1
# KV Sharma          1
# MS Gony            1
# Name: player_of_match, Length: 226, dtype: int64

# %% [markdown]
# #### 👉 We can conclude that most commanding player and the most number of man of the matches was won by "CH GAYLE", followed by "AB de Villiers just one man less".
# #### 👉 Also the least number of man of the match is bagged by SW BILLINGS

# %% [markdown]
# #### 👉 Which is the most successfull team in all seasons of IPL?

# %%
df1.winner.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
plt.figure(figsize=(11,6))
plt.xticks(rotation = 'vertical')
sns.countplot(x = 'winner', data = df1);

# %%
df1['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %% [markdown]
# #### 👉  We can conclude that the MUMBAI INDIANS is the most successfull team in all the IPL. They are followed by CSK  and KKR.

# %% [markdown]
# ### 👉 Which team is the most punctual team in all the seasons of IPL?

# %% [markdown]
# #### 👉 As it is a versus match we can count any column team1 or team2 as at the end of any season all teams would have same number of games.

# %%
df1['team1'].value_counts()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
plt.figure(figsize=(11,6))
plt.xticks(rotation = 'vertical')
sns.countplot(x = 'team1', data = df1);

# %% [markdown]
# #### 👉  Here also Mumbai Indians is the most consistent team around. In this format consistent refers, the teams or franchises that participated in every season of ipl.
# #### 👉 They were followed by Kings XI Punjab, CSK.

# %% [markdown]
# #### 👉 In which venue which team won the maximum number of matches.

# %%
df1.venue.unique()
# Out:
# array(['Rajiv Gandhi International Stadium, Uppal',
#        'Maharashtra Cricket Association Stadium',
#        'Saurashtra Cricket Association Stadium', 'Holkar Cricket Stadium',
#        'M Chinnaswamy Stadium', 'Wankhede Stadium', 'Eden Gardens',
#        'Feroz Shah Kotla',
#        'Punjab Cricket Association IS Bindra Stadium, Mohali',
#        'Green Park', 'Punjab Cricket Association Stadium, Mohali',
#        'Sawai Mansingh Stadium', 'MA Chidambaram Stadium, Chepauk',
#        'Dr DY Patil Sports Academy', 'Newlands', "St George's Park",
#        'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
# ...

# %%
plt.figure(figsize=(17,25))
plt.yticks(rotation = 70)
plt.xticks(rotation = 45)
sns.countplot(y = 'city',hue = 'winner', data = df1);

# %%
plt.figure(figsize=(17,25))
plt.xlabel(xlabel = "Matches Won")
plt.yticks(rotation = 70)
plt.xticks(rotation = 45)
sns.countplot(y = 'venue',hue = 'winner', data = df1);

# %% [markdown]
# #### 👉 Teams won by highest runs and wickets

# %%
first_bat_stats = df1[df1.win_by_runs != 0]
first_bat_stats
sns.histplot(x = 'win_by_runs', data = first_bat_stats);

# %%
first_bowl_stats = df1[df1.win_by_wickets != 0]
first_bowl_stats
sns.histplot(x = 'win_by_wickets', data = first_bowl_stats);

# %%
print('The highest run by which a team has ever won {}'.format(df1.win_by_runs.max()))
print('The highest wicket by which a team has ever won {}'.format(df1.win_by_wickets.max()))
# Out:
# The highest run by which a team has ever won 146
# The highest wicket by which a team has ever won 10

# %% [markdown]
# #### 👉 When won_by_runs, it means the team that has won the toss chose to bat first, so it is observed that when batted first a major percentage has won in the range of 0 to 50 runs.
#
# #### 👉 When won_by_wickets, it means team the team that has won the toss chose to bowl first, so it is observed that when bowled first the distribution of wickets taking is distributed proportionately.

# %% [markdown]
# #### 👉 Comparing winning chances against winning a toss

# %%
df1.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1       SPD Smith    Maharashtra Cricket Association Stadium

# %% [markdown]
# #### 👉 As we know the team that wins the toss they gets to choose whether they want to bowl first or bat first, they chooses this based on the pitch conditions. Lets compare the chances of winning a game by the toss winning team.

# %%
winning_team = df1.toss_winner == df1.winner

# %%
win = winning_team.value_counts()

# %%
win
# Out:
# True     393
# False    363
# dtype: int64

# %%
df1.id.count()
# Out:
# 756

# %%
win1 = win.index

# %% [markdown]
# #### 👉 Total matches that were played are 756 out of which 393 matches were won by the toss winning team and 363 matches were won by the team that lost the toss.

# %% [markdown]
# #### 👉 converting into percentage factor

# %%
toss_winning_win_percentage = (393/756)*100
toss_losing_win_percentage = (363/756)*100
print(f"Toss winning win percentage is {round(toss_winning_win_percentage,3)}%")
print(f"Toss losing win percentage is {round(toss_losing_win_percentage,3)}%")
# Out:
# Toss winning win percentage is 51.984%
# Toss losing win percentage is 48.016%

# %% [markdown]
# #### 👉 We can observe that the factor of winning a toss does not put much effect to the win rate of the team as the team winning toss has only a win rate percentage difference of 3% approx.

# %% [markdown]
# #### 👉 plotting pie chart

# %%
colors = ['gold', 'lightcoral']
plt.pie(win, labels = win1, autopct='%1.1f%%', shadow=True, startangle=140, colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f9ee2bfd00>,
# ...
#  [Text(-0.6532022488516823, -0.8850575247378586, 'True'),
#   Text(0.6532023317167454, 0.8850574635806463, 'False')],
#  [Text(-0.3562921357372812, -0.48275864985701367, '52.0%'),
#   Text(0.3562921809364065, 0.4827586164985343, '48.0%')])

# %% [markdown]
# ### 👉 Number of balls bowled by bowlers

# %%
df2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
plt.figure(figsize = (13,6))
plt.xlabel(xlabel = 'bowler_name')
plt.ylabel(ylabel = 'count')
bowler_stats = df2.bowler.value_counts()
bowler_stats1 = bowler_stats[:10]
sns.barplot(bowler_stats1.index, bowler_stats1);

# %% [markdown]
# #### 👉 Harbajan Singh has bowled the maximum number of time

# %% [markdown]
# ### 👉 Maximum wickets taken by bowlers

# %%
df2.sample(5)
# Out:
#         match_id  inning                 batting_team      bowling_team  over  \
# 57445        243       1          Chennai Super Kings   Kings XI Punjab    20
# 27491        118       2          Chennai Super Kings    Mumbai Indians     4
# 46817        199       1               Mumbai Indians   Deccan Chargers     4
# 28658        124       2  Royal Challengers Bangalore   Deccan Chargers     2
# 161112      7938       2  Royal Challengers Bangalore  Delhi Daredevils     8
#
#         ball       batsman     non_striker          bowler  is_super_over  \
# 57445      2      MS Dhoni     S Badrinath       RJ Harris              0
# 27491      2    A Flintoff       ML Hayden          Z Khan              0
# 46817      8  SR Tendulkar        DJ Bravo  Jaskaran Singh              0
# 28658      2     JH Kallis      RV Uthappa        RP Singh              0
# 161112     2       V Kohli  AB de Villiers        A Mishra              0
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
df2['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %% [markdown]
# #### 👉 Run out and retired hurt doesn't counts in favour of the bowler. So these types are eliminated

# %%
dismissed = df2[df2.dismissal_kind != 'run out']
dismissed1 = dismissed[dismissed.dismissal_kind != 'retired hurt']

# %%
dismissed1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178214 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          178214 non-null  int64
#  1   inning            178214 non-null  int64
#  2   batting_team      178214 non-null  object
#  3   bowling_team      178214 non-null  object
#  4   over              178214 non-null  int64
#  5   ball              178214 non-null  int64
#  6   batsman           178214 non-null  object
#  7   non_striker       178214 non-null  object
#  8   bowler            178214 non-null  object
#  9   is_super_over     178214 non-null  int64
#  10  wide_runs         178214 non-null  int64
#  11  bye_runs          178214 non-null  int64
#  12  legbye_runs       178214 non-null  int64
#  13  noball_runs       178214 non-null  int64
#  14  penalty_runs      178214 non-null  int64
#  15  batsman_runs      178214 non-null  int64
# ...

# %%
dismissed1.sample(5)
# Out:
#         match_id  inning                 batting_team  \
# 88950        376       2  Royal Challengers Bangalore
# 13293         57       1          Sunrisers Hyderabad
# 156177      7918       1          Sunrisers Hyderabad
# 18225         78       1             Rajasthan Royals
# 58565        248       1          Chennai Super Kings
#
#                        bowling_team  over  ball          batsman  \
# 88950               Deccan Chargers    10     6        SS Tiwary
# 13293         Kolkata Knight Riders     8     2        DA Warner
# 156177              Kings XI Punjab     8     1  Shakib Al Hasan
# 18225         Kolkata Knight Riders    17     3        RA Jadeja
# 58565   Royal Challengers Bangalore     3     3          M Vijay
#
#           non_striker           bowler  is_super_over  ...  bye_runs  \
# 88950         V Kohli         A Mishra              0  ...         0
# 13293   KS Williamson  NM Coulter-Nile              0  ...         0
# ...

# %%
total_dismissed = dismissed1.groupby('bowler').apply(lambda x : x['dismissal_kind'].dropna()).reset_index(name='Wickets')

# %%
count_of_wickets = total_dismissed.groupby('bowler').count().reset_index()

# %%
a = count_of_wickets.sort_values(by = 'Wickets', ascending = False)
top_bowlers = a.loc[:,['bowler','Wickets']][0:10]
top_bowlers
# Out:
#               bowler  Wickets
# 290       SL Malinga      170
# 6           A Mishra      156
# 110  Harbhajan Singh      150
# 227        PP Chawla      149
# 82          DJ Bravo      147
# 46           B Kumar      133
# 232         R Ashwin      125
# 296        SP Narine      122
# 326         UT Yadav      119
# 244        RA Jadeja      108

# %% [markdown]
# #### 👉 So malinga is the most successfull bowler of all seasons of IPL taking a total of 170 wickets.

# %% [markdown]
# #### 👉 Task Conclusion:

# %% [markdown]
# * Import the Numpy and Pandas Libraries.
# * Load the iris dataset.
# * We have dropped the umpire1, umpire2, umpire3 columns from the dataset as it is not needed according to the analysis that has been provided to us.
# * Now lets check the info again.
# * As we can see city, winner, player_of_match columns few are still null which can be settled later.
# * Total number of matches hosted by cities.
# * Total Number of matches played in different stadiums across seasons.
# * Mumbai in total hosted the maximum number of matches but Eden gardens of kolkata is recorded as the stadium where the maximum number of matches has been played.
# * Who is the most successfull player in the whole IPL tournament?.
# * As the countplot is large so to specify it correctly.
# * We can conclude that most commanding player and the most number of man of the matches was won by "CH GAYLE", followed by "AB de Villiers just one man less".
# * Also the least number of man of the match is bagged by SW BILLINGS.
# * Which is the most successfull team in all seasons of IPL?.
# * We can conclude that the MUMBAI INDIANS is the most successfull team in all the IPL. They are followed by CSK and KKR.
# * Which team is the most punctual team in all the seasons of IPL.
# * As it is a versus match we can count any column team1 or team2 as at the end of any season all teams would have same number of games.
# * Here also Mumbai Indians is the most consistent team around. In this format consistent refers, the teams or franchises that participated in every season of IPL.
# * They were followed by Kings XI Punjab, CSK.
# * In which venue which team won the maximum number of matches.
# * Teams won by highest runs and wickets.
# * When won_by_runs, it means the team that has won the toss chose to bat first, so it is observed that when batted first a major percentage has won in the range of 0 to 50 runs.
# * When won_by_wickets, it means team the team that has won the toss chose to bowl first, so it is observed that when bowled first the distribution of wickets taking is distributed proportionately.
# * Comparing winning chances against winning a toss.
# *  As we know the team that wins the toss they gets to choose whether they want to bowl first or bat first, they chooses this based on the pitch conditions. Lets compare the chances of winning a game by the toss winning team.
# * Total matches that were played are 756 out of which 393 matches were won by the toss winning team and 363 matches were won by the team that lost the toss.
# * converting into percentage factor.
# * We can observe that the factor of winning a toss does not put much effect to the win rate of the team as the team winning toss has only a win rate percentage difference of 3% approx.
# * plotting pie chart.
# * Number of balls bowled by bowlers.
# * Harbajan Singh has bowled the maximum number of time.
# * Maximum wickets taken by bowlers.
# * Run out and retired hurt doesn't counts in favour of the bowler. So these types are eliminated.
# *  So malinga is the most successfull bowler of all seasons of IPL taking a total of 170 wickets.
# * A particular sports company should endorse for such a team that is successfull, has a maximum win percentage rate, is displined and has continuous presence in every season of IPL. Such a team if you see is MUMBAI INDIANS, their win rate is high, and they also satisfies each of the factors that must be fulfilled. CSK, RCB are also teams that they can endorse.
#
# * If you consider bowler then Amir Mishra, Harbajan Singh, Bravo, B Kumar can be a good option to endorse for their products. Malinga and Chawla have retired so could not include them. Specially the wicket taking bowlers are the most popular, so slecting in the basis of this fact wont be a bad option.
#
# * For batsman AB de Villiers, Virat Kohli and more options are present who can be profitable is a company endorse for its products in partnership to them.
